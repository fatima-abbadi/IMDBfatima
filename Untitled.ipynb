# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Load the dataset
df = pd.read_csv('imdb_top_1000.csv')
print(df)
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
# Handle missing values
df = df.dropna(axis=0)
print(df)
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 990  https://m.media-amazon.com/images/M/MV5BYjRmY2...
# 991  https://m.media-amazon.com/images/M/MV5BMzAyND...
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# 994  https://m.media-amazon.com/images/M/MV5BZjQyMG...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
# Count the occurrences of each genre
genre_counts = df['Genre'].value_counts()

# Print the most popular genre
most_popular_genre = genre_counts.idxmax()
print("The most popular genre:", most_popular_genre)
# Out:
# The most popular genre: Drama

# %%
# Count the occurrences of each genre
genre_counts = df['Genre'].value_counts()

# Create a new dataframe with the genre counts
genre_counts_df = pd.DataFrame(genre_counts).reset_index()
genre_counts_df.columns = ['Genre', 'Count']

# Print the dataframe
print(genre_counts_df)
# Out:
#                           Genre  Count
# 0                         Drama     58
# 1                Drama, Romance     26
# 2                 Comedy, Drama     24
# 3        Crime, Drama, Thriller     22
# 4     Action, Adventure, Sci-Fi     21
# ..                          ...    ...
# 167  Crime, Film-Noir, Thriller      1
# 168   Drama, Film-Noir, Romance      1
# 169     Drama, History, Romance      1
# 170   Adventure, Horror, Sci-Fi      1
# 171      Comedy, Music, Musical      1
#
# [172 rows x 2 columns]

# %%
# Create a figure with custom size
plt.figure(figsize=(100, 20))

# Create a bar chart
plt.bar(genre_counts_df['Genre'], genre_counts_df['Count'])
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Most Popular Genre of  Shows/Fatima Abbadi')
plt.xticks(rotation=90)

# Show the chart
plt.show()

# %%
# Count the occurrences of each director
director_counts = df['Director'].value_counts()

# Create a new dataframe with the director counts
director_counts_df = pd.DataFrame(director_counts).reset_index()
director_counts_df.columns = ['Director', 'Count']

# Sort the dataframe by count in descending order
director_counts_df = director_counts_df.sort_values(by='Count', ascending=False)

# Print the dataframe
print(director_counts_df)
# Out:
#               Director  Count
# 0     Steven Spielberg     13
# 1      Martin Scorsese     10
# 2     Alfred Hitchcock      9
# 3    Christopher Nolan      8
# 4       Clint Eastwood      8
# ..                 ...    ...
# 232       Nathan Greno      1
# 233     Paul Verhoeven      1
# 234        Paul Haggis      1
# 235       Stephen Chow      1
# 401     Richard Lester      1
#
# [402 rows x 2 columns]

# %%
# Create a bar chart
plt.bar(director_counts_df['Director'], director_counts_df['Count'])
plt.xlabel('Director')
plt.ylabel('Count')
plt.title('Top Rated Movies/TV Shows by Director')
plt.xticks(rotation=90)

# Show the chart
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(director_df['Director'][:10], director_df['Count'][:10])
plt.xlabel('Director')
plt.ylabel('Count')
plt.title('Director with the Most Top-rated Movies/TV Shows')
plt.xticks(rotation=90)
plt.show()

# %%
#The IMDB dataset was downloaded from Kaggle and loaded into a pandas dataframe using the read_csv() function.
#The data was cleaned and preprocessed by removing unnecessary columns and handling missing values.
#The data was explored to identify the most popular genre of movies and TV shows using pandas.
#A new dataframe was created to contain the count of movies/TV shows in each genre using pandas.
#The data was visualized using a bar chart to show the most popular genre of movies/TV shows using pandas and the matplotlib library.
#The director with the most top-rated movies/TV shows was identified by creating a new dataframe containing the count of movies/TV shows directed by each director using pandas.
#The data was visualized using a bar chart to show the director with the most top-rated movies/TV shows using pandas and matplotlib.
